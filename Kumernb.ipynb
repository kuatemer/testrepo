# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b> M Kuate </b> <br> Data Scientist</br>

# %% [markdown]
# _I am interested in Data science because I have always been curious about data and the meaning behind data in the healthcare industry_

# %% [markdown]
# ### my code in the next cell  will calculate and give the result of 10+10

# %%
print (10+10)
# Out:
# 20

# %% [markdown]
# > My friends and their Kids.
# -  Leonie
# 1. Jeyden
# 2. Raphael
# 3. Michelle
# - Leonel
# 1. Andy
# 2. Aden
